# %%
a = [50,58,47,48,67]
E=50
z=0
for i in a:
    z = z + ((i-50)**2/50)
print("Chi-square distibution = " , z)
# Out:
# Chi-square distibution =  7.32

# %%
import scipy.stats as stats
stats.chisquare(a, 50)
# Out:
# Power_divergenceResult(statistic=7.3200000000000003, pvalue=0.11991350930483732)

# %%
F=[60,54,46,41] #creating array variables for female
Ftot =201 #assigning the total number of female to Ftot
M=[40,44,53,57] #creating array variables for male
Mtot=199 #assigning the total number of Male to Mtot
Tot=[100,98,99,98] #creating array variables for the total number of people participated
Fx=[] # a null array to store the female expected value
Mx=[] # a null array to store  the male expected value
valf=0  # variable to store the value of Fx
for i in Tot:
    valf=i*(201/395)
    Fx.append(valf)
    print("Expected Female ",Fx)
valm=0 # variable to store the value of Mx
for i in Tot:
    valm=(i*194/395)
    Mx.append(valm)
print("Expected Male ",Mx
u=v=0 # chi-square distribution for female and male respectively
for i in range(0,4):
    u=u+((F[i]-Fx[i])**2)/Fx[i]
    v=v+((M[i]-Mx[i])**2)/Mx[i]
print("Female chisquare=",u)
print("Male Chisquare=",v)  
print("Mean Chi Square =",(u+v))
